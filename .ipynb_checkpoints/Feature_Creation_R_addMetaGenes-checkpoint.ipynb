# %%
# Load Libraries

suppressPackageStartupMessages( library(dplyr, quietly = T))
suppressPackageStartupMessages(library(GenomicRanges, quietly = T))
suppressPackageStartupMessages(library(foreach, quietly = T))
suppressPackageStartupMessages(library(doParallel, quietly = T))
suppressPackageStartupMessages(library(xgboost, quietly = T))
suppressPackageStartupMessages(library(ggplot2, quietly = T))
suppressPackageStartupMessages(library(data.table, quietly = T))
suppressPackageStartupMessages(library(biomaRt))

# %% [markdown]
# Information about data:
# - CAGE-train ("data/CAGE-train"): includes information about gene location and expression. X1 and X2 has train/val info/y, X3 only has test info that we should test on (only testing on chr1).
# - DNase-seq: information on chromatin accessibility (reads only in open chromatin)
# - bed, bigwig: genomic regions and associated annotations
# - do not use H3K9me3, distribution too different among X1, X2, X3

# %% [markdown]
# ## Work Package 1.1 - Modeling Choices & Data Pre-processing

# %%
############################ READ IN DATA ####################################

files <- list.files("./ML4G_Project_1_Data/")
bed_files <- files[stringr::str_detect(files,"-bed")]

# Load the beds, join them and convert them to genomic range objects and 
# store them in a list

cell_lines <- c("X1","X2","X3")

beds <- list()
beds2 <- list()

for (cell_line in cell_lines) {
  temp <- list()
  for (bed_file in bed_files) {
    
    tempII <- data.table::fread(paste0(c("./ML4G_Project_1_Data/",bed_file,"/",cell_line,".bed"),collapse = ""))
    if(bed_file == "DNase-bed" ){ 
      tempII$score <- tempII$V7
      tempII$score_scaled <- scale(tempII$V7) + 2
    } else {
      tempII$score <- tempII$V5
      tempII$score_scaled <- scale(tempII$V5) + 2
    }

    tempII$type <- bed_file
    
    temp[[bed_file]] <- tempII

  }
  
  beds[[cell_line]] <- data.table::rbindlist(temp) 
  beds[[cell_line]]$type <- as.factor(  beds[[cell_line]]$type )
    
  beds2[[cell_line]] <- beds[[cell_line]]
  beds2[[cell_line]]$cell_line <- cell_line
    
  beds[[cell_line]] <-beds[[cell_line]]  %>% GenomicRanges::makeGRangesFromDataFrame(
                                            keep.extra.columns = T,
                                            seqnames.field = "V1",
                                            start.field = "V2",
                                            end.field = "V3")
  

}

# %%
# Plot un-normalized and normalized distribtuion of scores
all_peaks <- data.table::rbindlist(beds2)

ggplot(all_peaks, aes(x=score,fill=cell_line)) + 
  geom_density(alpha=.4) + facet_grid(type ~ .) + xlim(0,400)

ggplot(all_peaks, aes(x=score_scaled,fill=cell_line)) + 
  geom_density(alpha=.4) + facet_grid(type ~ .) + xlim(0,6)
# Out:
# Warning message:
# “Removed 35222 rows containing non-finite values (stat_density).”Warning message:
# “Removed 11150 rows containing non-finite values (stat_density).”
# plot without title
# plot without title

# %% [markdown]
# Here we plotted the distribution of scores obtained from different datasets look like, and also observed how the score distribution seemed after normalization. Based on the plot we concluded that normalization did not make a big difference in terms of performance and thus proceeded with non-normalized scores.
#
# Next we load in the genes for each set, train, validation and test and retreive additonal data concerning the genes from ensembl with their biomart tool and avarged tissue specific expression data from GTEX.

# %%
# Load the genes and create GRanges

genesTrain <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X1_train_info.tsv")
genesVal <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X1_val_info.tsv")
genesTest <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X3_test_info.tsv")

genes <- rbind(genesTrain,genesVal) %>% 
  rbind(genesTest) %>%
  GenomicRanges::makeGRangesFromDataFrame(
    keep.extra.columns = T,
    seqnames.field = "chr",
    start.field = "TSS_start",
    end.field = "TSS_end",
    strand.field = "strand")


data_url <- "https://storage.googleapis.com/gtex_analysis_v8/rna_seq_data/GTEx_Analysis_2017-06-05_v8_RNASeQCv1.1.9_gene_median_tpm.gct.gz"
gene_expression_data <- readr::read_tsv(gzcon(url(data_url)), skip = 2,col_names = TRUE)

ensembl <- useEnsembl(biomart = "ensembl",
                      dataset = "hsapiens_gene_ensembl")


meta_genes <- getBM(attributes = c("ensembl_gene_id",
                                   "ensembl_gene_id_version",
                                   "transcript_count",
                                   "percentage_gene_gc_content",
                                   "hgnc_symbol",
                                   "description",
                                   "gene_biotype",
                                   "strand",
                                   "external_gene_name"),
                    filters = "ensembl_gene_id",
                    values = sapply(strsplit(gene_expression_data$Name,"\\."),"[[",1),
                    mart = ensembl)

gene_expression_data$ensemblid <- sapply(strsplit(gene_expression_data$Name,"\\."),"[[",1)

new <-gene_expression_data %>%
  left_join(meta_genes,by=c("ensemblid"="ensembl_gene_id"))

new <- distinct(new[order(-rowMeans(new[,3:50])),],hgnc_symbol,.keep_all = T)

new <- as.data.frame(new[!is.na(new$hgnc_symbol),])

rownames(new) <- new$hgnc_symbol

new$mean_expression <- rowMeans(new[,3:56], na.rm = TRUE)
new$max_expression <- apply(new[,3:56], 1, max, na.rm = TRUE)
new$min_expression <- apply(new[,3:56], 1, min, na.rm = TRUE)


geneMetaData <- new[genes$gene_name,59:68]

geneMetaData$gene_biotype <- as.factor(geneMetaData$gene_biotype)
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   Name = col_character(),
#   Description = col_character()
# )
# See spec(...) for full column specifications.
# Cache found

# %%
# define gene set indices store in list for for loop

train_and_val_inds <- which(genes$gene_name %in% c(genesTrain$gene_name,genesVal$gene_name))
test_inds <- which(genes$gene_name %in% genesTest$gene_name)

cell_line_gene_inds <- list(train_and_val_inds,
                         train_and_val_inds,
                         test_inds)

# %%
# Define the inner "receptive field"

inner_rF <- 5000
outer_rF <- 200000

# Use the promoters function to expand the gene ranges around the TSS by +- rF

shortIntevals <- promoters(genes,
                          upstream  = inner_rF,
                          downstream= inner_rF)

longIntervals <- promoters(genes,
                          upstream  = outer_rF ,
                          downstream= outer_rF)

# 
geneOverlaps <- findOverlaps(longIntervals,shortIntevals) %>%
                as.data.frame()

# Split single DF into list of DFs
geneOverlaps <- split(geneOverlaps,f = geneOverlaps$queryHits)

# %%
########################## CREATE FEATURES ##################################

# Register the parallel backend

num_cores <- 3
registerDoParallel(cores = num_cores)


res <- foreach(j = 1:3, .packages = c("dplyr","GenomicRanges")) %dopar% {
  features  <- list() # Initialize features for cell line j
  
  shortOverlaps <- findOverlaps(shortIntevals,beds[[cell_lines[j]]]) %>%
                   as.data.frame() %>%
                   mutate(queryHits = factor(queryHits,levels = 1:length(genes))) %>%
                   group_by(queryHits,.drop = FALSE) %>%
                   group_split()
  
  LongOverlaps <- findOverlaps(longIntervals,beds[[cell_lines[j]]]) %>%
                  as.data.frame() %>%
                  mutate(queryHits = factor(queryHits,levels = 1:length(genes))) %>%
                  group_by(queryHits,.drop = FALSE) %>%
                  group_split()
            
  
  for (i in cell_line_gene_inds[[j]]) {
    
    feature_bed <- numeric(183) # Number of features
    
    shortInteval <- shortIntevals[i]
          
    longInterval <- longIntervals[i]
    
    geneNeigbourhoodData <- shortIntevals[geneOverlaps[[i]]$subjectHits]
    
    shortRangeData <- beds[[cell_lines[j]]][shortOverlaps[[i]]$subjectHits] 
    
    longRangeData <- beds[[cell_lines[j]]][LongOverlaps[[i]]$subjectHits]
    
    peaks_close_to_a_tssInds <- findOverlaps(geneNeigbourhoodData,longRangeData)
    peaks_not_close_to_a_tssData <- longRangeData[-(peaks_close_to_a_tssInds@to)]
    
    offset <- 0
    for (bed_file in bed_files) {
      
      peaks <- shortRangeData[shortRangeData$type ==  bed_file]
      peaks_distal <- longRangeData[longRangeData$type ==  bed_file]
      peaks_lonely_distal <- peaks_not_close_to_a_tssData[peaks_not_close_to_a_tssData$type ==  bed_file]
      
      feature_bed[1+offset] <- length(peaks) #number_of_peaks
      feature_bed[2+offset] <- length(peaks_distal) - length(peaks) #number_of_distal_peaks
      feature_bed[3+offset] <- length(peaks_lonely_distal) # number_of_distal_lonely_peaks

      
      if (feature_bed[1+offset] > 0) {


        peak_centers <- (start(peaks) + end(peaks)) / 2
        
        center_dis <- peak_centers - ((start(shortInteval) + end(shortInteval))) / 2
        feature_bed[4+offset] <- center_dis[which.min(abs(center_dis))] #distance_to_closest_peak_signed
        feature_bed[5+offset] <- center_dis[which.max(abs(center_dis))] #distance_to_furthest_peak_signed
        feature_bed[6+offset] <- min(abs(center_dis))                 # distance_to_closest_peak_unsigned
        feature_bed[7+offset] <- sum(peaks$score) #sum_of_scores
        feature_bed[8+offset] <- peaks[which.min(abs(center_dis)), ]$score #score_of_closet_peak
        feature_bed[9+offset] <- peaks[which.max(abs(center_dis)), ]$score #score_of_furthest_peak
        feature_bed[10+offset] <- max(peaks$score) #max_peak
        feature_bed[11+offset] <- mean(peaks$score) #mean_peak
        
        # Binned Peak score sum vectors
        
        intervals <- seq(start(shortInteval),end(shortInteval) + 50,by=1000)
        intervals[1]  <- intervals[1]  - 100000
        intervals[11] <- intervals[11] + 100000
        bincodes <- .bincode(peak_centers,intervals)
        for (r in 1:length(peaks)) {
          feature_bed[11+offset+bincodes[r]] <- feature_bed[11+offset+bincodes[r]] + peaks[r]$score
        }
        
        
      } else{
        
        feature_bed[4+offset] <- 1000000 #distance_to_closest_peak_signed
        feature_bed[5+offset] <- 1000000 #distance_to_furthest_peak_signed
        feature_bed[6+offset] <- 1000000 #distance_to_closest_peak_unsigned
        feature_bed[7+offset] <- 0 #sum_of_scores
        feature_bed[8+offset] <- 0 #score_of_closet_peak
        feature_bed[9+offset] <- 0 #score_of_furthest_peak
        feature_bed[10+offset] <- 0 #max_peak
        feature_bed[11+offset] <- 0#mean_peak
        
      }
      if (feature_bed[2+offset] > 0) {
        feature_bed[22+offset] <- sum(peaks_distal$score) - feature_bed[7+offset] # sum_of_scores_distal
        feature_bed[23+offset] <- feature_bed[22+offset]/feature_bed[2+offset] # mean_of_score_distal
        # Add distance to closest distal peak ??? 
      } else {
        feature_bed[22+offset] <- 0 # sum_of_scores_distal
        feature_bed[23+offset] <- 0 # mean_of_score_distal
      }
      if(feature_bed[3+offset]> 0){
        feature_bed[24+offset] <- max(peaks_lonely_distal$score) # lonely_distal_max
        feature_bed[25+offset] <- mean(peaks_lonely_distal$score) # lonely_distal_mean
      } else {
        feature_bed[24+offset] <- 0 # lonely_distal_max
        feature_bed[25+offset] <- 0 # lonely_distal_mean
      }
      offset <- offset + 25
    }


    feature_bed[176] <- (genes[i]$gene_end - genes[i]$gene_start) # gene_length
    feature_bed[177] <- length(geneNeigbourhoodData) - 1 # number_of_genes_in_large_neighbourhood
    feature_bed[178] <- as.numeric(strand(genes[i]) == "+") # Strand
    feature_bed[179] <- geneMetaData$transcript_count[i]
    feature_bed[180] <- geneMetaData$percentage_gene_gc_content[i]
    feature_bed[181] <- geneMetaData$mean_expression[i]
    feature_bed[182] <- geneMetaData$max_expression[i]
    feature_bed[183] <- geneMetaData$min_expression[i]
      
    feature_bed <-  c(feature_bed,as.numeric(levels(geneMetaData$gene_biotype[i]) == geneMetaData$gene_biotype[i]))
    
    features[[genes[i]$gene_name]] <- feature_bed
    
  }
  features
}
stopImplicitCluster()

# %%
# Create data.frames of the results 
# Load response vars

train_vals_x1 <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X1_train_y.tsv")
train_vals_x2 <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X2_train_y.tsv")

validation_vals_x1 <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X1_val_y.tsv")
validation_vals_x2 <- data.table::fread("./ML4G_Project_1_Data/CAGE-train/X2_val_y.tsv")

features <- c("number_of_peaks",
              "number_of_distal_peaks",
              "number_of_distal_lonely_peaks",
              "distance_to_closest_peak_signed",
              "distance_to_furthest_peak_signed",
              "distance_to_closest_peak_unsigned",
              "sum_of_scores",
              "score_of_closet_peak",
              "score_of_furthest_peak",
              "max_peak",
              "mean_peak",
              paste0("bin_",1:10),
              "sum_of_scores_distal",
              "mean_of_score_distal",
              "lonely_distal_max",
              "lonely_distal_mean"
              
              
)


feature_cols <- c()
for (bed_file in bed_files) {
  feature_cols <- c(feature_cols,paste0(features,"_",strsplit(bed_file,"-bed")[[1]]))
}
feature_cols <- c(feature_cols,
                  "gene_length",
                  "number_of_genes_in_large_neighbourhood",
                  "strand",
                  "transcript_count",
                  "percentage_gene_gc_content",
                  "mean_expression",
                  "max_expression",
                  "min_expression",
                  levels(geneMetaData$gene_biotype))

# GET DATA INTO RIGHT ORDER

examine <- data.frame(res[[1]]) 
rownames(examine) <- feature_cols


x1_feat <- data.frame(t(data.frame(res[[1]])))
colnames(x1_feat) <- feature_cols

rownames(x1_feat) <-  c(train_vals_x1$gene_name,validation_vals_x1$gene_name)
x1_feat$y_val <- c(train_vals_x1$gex,validation_vals_x1$gex)


x2_feat <- data.frame(t(data.frame(res[[2]])))
colnames(x2_feat) <- feature_cols

rownames(x2_feat) <-  c(train_vals_x2$gene_name,validation_vals_x2$gene_name)
x2_feat$y_val <- c(train_vals_x2$gex,validation_vals_x2$gex)

x3_feat <- data.frame(t(data.frame(res[[3]])))
colnames(x3_feat) <- feature_cols
rownames(x3_feat) <-  c(genesTest$gene_name)


train_complete <-data.frame(rbind(x1_feat[train_vals_x1$gene_name,],
                                  x2_feat[train_vals_x2$gene_name,]))

val_complete <-data.frame(rbind(x1_feat[rownames(x1_feat) %in% validation_vals_x1$gene_name  ,],
                                x2_feat[rownames(x2_feat) %in% validation_vals_x2$gene_name,]))

test_complete <- x3_feat

# %%
# Make this example reproducible
set.seed(0)

# Test using only certain features
train_complete<- train_complete %>%
  dplyr::select(-contains("H3K9me3"))

val_complete<- val_complete %>%
  dplyr::select(-contains("H3K9me3"))

train_complete<- train_complete %>%
  dplyr::select(-contains("H3K9me3"))

#train_complete<- train_complete %>%
#  select(-contains("expression"))
#
#val_complete<- val_complete %>%
#  select(-contains("expression"))
#
#train_complete<- train_complete %>%
#  select(-contains("expression"))

#define final training and testing sets
 

xgb_train = xgb.DMatrix(data =  data.matrix(train_complete[,-ncol(train_complete)]),
                        label = train_complete[,ncol(train_complete)])

xgb_test = xgb.DMatrix(data = data.matrix(val_complete[,-ncol(val_complete)]),
                       label = val_complete[,ncol(val_complete)])

test_complete <- test_complete %>%
  dplyr::select(-contains("H3K9me3"))

xgb_real_test = xgb.DMatrix(data = data.matrix(test_complete))

# %% [markdown]
# ## Work Package 1.2 - Model Building

# %%
# Create XGboost watchlist to monitor the training

watchlist = list(train=xgb_train, test=xgb_test)

# Create a evalation function to use to montior the training

evalerror <- function(preds, dtrain) {
  labels <- getinfo(dtrain, "label")
  err <- cor(labels , preds,method = "spearman")
  return(list(metric = "spearman", value = err))
}


# Define a set of parameters to use (thse)

param <- list(objective = "count:poisson",
                          eval_metric = evalerror,
                           subsample = 0.7,
                           colsample_bytree= 0.4,
                           lambda = 100,
                           alpha = 750)

# %%
# Train a XGboost model with the above parameters (monitor loss to find optimal nrounds)
model = xgb.train(data = xgb_train,
                  max.depth = 6,
                  watchlist=watchlist,
                  nrounds = 500,
                  params = param)
# Out:
# [1]	train-spearman:0.607755	test-spearman:0.599236
# [2]	train-spearman:0.625377	test-spearman:0.615694
# [3]	train-spearman:0.634525	test-spearman:0.621675
# [4]	train-spearman:0.637859	test-spearman:0.623057
# [5]	train-spearman:0.640952	test-spearman:0.629272
# [6]	train-spearman:0.648042	test-spearman:0.639987
# [7]	train-spearman:0.653948	test-spearman:0.641721
# [8]	train-spearman:0.667400	test-spearman:0.657241
# [9]	train-spearman:0.689571	test-spearman:0.687269
# [10]	train-spearman:0.694411	test-spearman:0.692169
# [11]	train-spearman:0.696156	test-spearman:0.694218
# [12]	train-spearman:0.701355	test-spearman:0.700914
# [13]	train-spearman:0.711203	test-spearman:0.715890
# [14]	train-spearman:0.730144	test-spearman:0.736255
# [15]	train-spearman:0.735810	test-spearman:0.740415
# [16]	train-spearman:0.739540	test-spearman:0.743860
# [17]	train-spearman:0.743899	test-spearman:0.748323
# [18]	train-spearman:0.747889	test-spearman:0.754056
# [19]	train-spearman:0.749843	test-spearman:0.758427
# [20]	train-spearman:0.751373	test-spearman:0.759643
# [21]	train-spearman:0.754989	test-spearman:0.761964
# [22]	train-spearman:0.755366	test-spearman:0.760980
# [23]	train-spearman:0.760657	test-spearman:0.768337
# [24]	train-spearman:0.762681	test-spearman:0.770360
# [25]	train-spearman:0.763543	test-spearman:0.770141
# [26]	train-spearman:0.764321	test-spearman:0.772041
# [27]	train-spearman:0.764053	test-spearman:0.771714
# [28]	train-spearman:0.763984	test-spearman:0.773646
# [29]	train-spearman:0.764575	test-spearman:0.774419
# [30]	train-spearman:0.765020	test-spearman:0.775928
# [31]	train-spearman:0.765495	test-spearman:0.776728
# [32]	train-spearman:0.765863	test-spearman:0.776955
# [33]	train-spearman:0.766886	test-spearman:0.777783
# [34]	train-spearman:0.767087	test-spearman:0.778562
# [35]	train-spearman:0.766911	test-spearman:0.778284
# [36]	train-spearman:0.767177	test-spearman:0.779120
# [37]	train-spearman:0.767521	test-spearman:0.779357
# [38]	train-spearman:0.767470	test-spearman:0.779172
# [39]	train-spearman:0.767735	test-spearman:0.779606
# [40]	train-spearman:0.767818	test-spearman:0.780147
# [41]	train-spearman:0.768239	test-spearman:0.780711
# [42]	train-spearman:0.768629	test-spearman:0.781102
# [43]	train-spearman:0.768769	test-spearman:0.780839
# [44]	train-spearman:0.768620	test-spearman:0.780974
# [45]	train-spearman:0.769000	test-spearman:0.781514
# [46]	train-spearman:0.768934	test-spearman:0.781335
# [47]	train-spearman:0.769133	test-spearman:0.781504
# [48]	train-spearman:0.769477	test-spearman:0.781684
# [49]	train-spearman:0.769936	test-spearman:0.782433
# [50]	train-spearman:0.770148	test-spearman:0.783118
# [51]	train-spearman:0.770837	test-spearman:0.783496
# [52]	train-spearman:0.770859	test-spearman:0.783468
# [53]	train-spearman:0.770961	test-spearman:0.783645
# [54]	train-spearman:0.771114	test-spearman:0.783708
# [55]	train-spearman:0.771519	test-spearman:0.784429
# [56]	train-spearman:0.771685	test-spearman:0.784376
# [57]	train-spearman:0.772007	test-spearman:0.784546
# [58]	train-spearman:0.771905	test-spearman:0.784394
# [59]	train-spearman:0.772353	test-spearman:0.784838
# [60]	train-spearman:0.773081	test-spearman:0.785368
# [61]	train-spearman:0.773606	test-spearman:0.785613
# [62]	train-spearman:0.773893	test-spearman:0.786177
# [63]	train-spearman:0.774308	test-spearman:0.786530
# [64]	train-spearman:0.774510	test-spearman:0.786175
# [65]	train-spearman:0.774674	test-spearman:0.786259
# [66]	train-spearman:0.774648	test-spearman:0.786424
# [67]	train-spearman:0.775169	test-spearman:0.787026
# [68]	train-spearman:0.775670	test-spearman:0.787415
# [69]	train-spearman:0.775995	test-spearman:0.787792
# [70]	train-spearman:0.776158	test-spearman:0.787596
# [71]	train-spearman:0.776080	test-spearman:0.787232
# [72]	train-spearman:0.776207	test-spearman:0.787582
# [73]	train-spearman:0.776658	test-spearman:0.787670
# [74]	train-spearman:0.776552	test-spearman:0.787586
# [75]	train-spearman:0.776980	test-spearman:0.787857
# [76]	train-spearman:0.776981	test-spearman:0.787705
# [77]	train-spearman:0.777072	test-spearman:0.787905
# [78]	train-spearman:0.777436	test-spearman:0.788343
# [79]	train-spearman:0.777595	test-spearman:0.788693
# [80]	train-spearman:0.777768	test-spearman:0.788715
# [81]	train-spearman:0.778133	test-spearman:0.789077
# [82]	train-spearman:0.778243	test-spearman:0.789137
# [83]	train-spearman:0.778218	test-spearman:0.789283
# [84]	train-spearman:0.778498	test-spearman:0.789382
# [85]	train-spearman:0.778570	test-spearman:0.789301
# [86]	train-spearman:0.778812	test-spearman:0.789378
# [87]	train-spearman:0.778744	test-spearman:0.789615
# [88]	train-spearman:0.778828	test-spearman:0.789959
# [89]	train-spearman:0.778646	test-spearman:0.790153
# [90]	train-spearman:0.778747	test-spearman:0.790113
# [91]	train-spearman:0.779089	test-spearman:0.790387
# [92]	train-spearman:0.779300	test-spearman:0.790647
# [93]	train-spearman:0.779444	test-spearman:0.790700
# [94]	train-spearman:0.779520	test-spearman:0.790762
# [95]	train-spearman:0.779660	test-spearman:0.790944
# [96]	train-spearman:0.779884	test-spearman:0.790808
# [97]	train-spearman:0.780194	test-spearman:0.791107
# [98]	train-spearman:0.780286	test-spearman:0.791128
# [99]	train-spearman:0.780151	test-spearman:0.790997
# [100]	train-spearman:0.780132	test-spearman:0.791006
# [101]	train-spearman:0.780182	test-spearman:0.790983
# [102]	train-spearman:0.780320	test-spearman:0.791140
# [103]	train-spearman:0.780256	test-spearman:0.791148
# [104]	train-spearman:0.780506	test-spearman:0.791471
# [105]	train-spearman:0.780094	test-spearman:0.791261
# [106]	train-spearman:0.779902	test-spearman:0.791196
# [107]	train-spearman:0.779952	test-spearman:0.791206
# [108]	train-spearman:0.779913	test-spearman:0.791255
# [109]	train-spearman:0.780072	test-spearman:0.791149
# [110]	train-spearman:0.780276	test-spearman:0.791212
# [111]	train-spearman:0.780419	test-spearman:0.791420
# [112]	train-spearman:0.780517	test-spearman:0.791429
# [113]	train-spearman:0.780695	test-spearman:0.791560
# [114]	train-spearman:0.780645	test-spearman:0.791695
# [115]	train-spearman:0.780875	test-spearman:0.791931
# [116]	train-spearman:0.781009	test-spearman:0.792012
# [117]	train-spearman:0.781060	test-spearman:0.792003
# [118]	train-spearman:0.781537	test-spearman:0.791890
# [119]	train-spearman:0.781684	test-spearman:0.791882
# [120]	train-spearman:0.781941	test-spearman:0.792129
# [121]	train-spearman:0.782292	test-spearman:0.792271
# [122]	train-spearman:0.782337	test-spearman:0.792405
# [123]	train-spearman:0.782495	test-spearman:0.792453
# [124]	train-spearman:0.782614	test-spearman:0.792490
# [125]	train-spearman:0.782826	test-spearman:0.792689
# [126]	train-spearman:0.782952	test-spearman:0.792853
# [127]	train-spearman:0.783074	test-spearman:0.792983
# [128]	train-spearman:0.783300	test-spearman:0.793166
# [129]	train-spearman:0.783419	test-spearman:0.793080
# [130]	train-spearman:0.783523	test-spearman:0.793042
# [131]	train-spearman:0.783852	test-spearman:0.793102
# [132]	train-spearman:0.783827	test-spearman:0.793205
# [133]	train-spearman:0.783739	test-spearman:0.793122
# [134]	train-spearman:0.783728	test-spearman:0.793104
# [135]	train-spearman:0.783822	test-spearman:0.793186
# [136]	train-spearman:0.783876	test-spearman:0.793316
# [137]	train-spearman:0.783878	test-spearman:0.793239
# [138]	train-spearman:0.783835	test-spearman:0.793208
# [139]	train-spearman:0.783956	test-spearman:0.793283
# [140]	train-spearman:0.784143	test-spearman:0.793354
# [141]	train-spearman:0.784319	test-spearman:0.793496
# [142]	train-spearman:0.784413	test-spearman:0.793501
# [143]	train-spearman:0.784481	test-spearman:0.793594
# [144]	train-spearman:0.784583	test-spearman:0.793693
# [145]	train-spearman:0.784563	test-spearman:0.793823
# [146]	train-spearman:0.784731	test-spearman:0.793880
# [147]	train-spearman:0.784765	test-spearman:0.793850
# [148]	train-spearman:0.784955	test-spearman:0.794059
# [149]	train-spearman:0.784957	test-spearman:0.794068
# [150]	train-spearman:0.785256	test-spearman:0.794257
# [151]	train-spearman:0.785108	test-spearman:0.794214
# [152]	train-spearman:0.785328	test-spearman:0.794208
# [153]	train-spearman:0.785316	test-spearman:0.794200
# [154]	train-spearman:0.785271	test-spearman:0.794142
# [155]	train-spearman:0.785305	test-spearman:0.794146
# [156]	train-spearman:0.785372	test-spearman:0.794118
# [157]	train-spearman:0.785567	test-spearman:0.794124
# [158]	train-spearman:0.785601	test-spearman:0.794062
# [159]	train-spearman:0.785582	test-spearman:0.794012
# [160]	train-spearman:0.785661	test-spearman:0.794018
# [161]	train-spearman:0.785744	test-spearman:0.794075
# [162]	train-spearman:0.785980	test-spearman:0.794062
# [163]	train-spearman:0.785995	test-spearman:0.793913
# [164]	train-spearman:0.786105	test-spearman:0.793955
# [165]	train-spearman:0.786126	test-spearman:0.794010
# [166]	train-spearman:0.786229	test-spearman:0.794047
# [167]	train-spearman:0.786330	test-spearman:0.794030
# [168]	train-spearman:0.786733	test-spearman:0.794283
# [169]	train-spearman:0.786707	test-spearman:0.794262
# [170]	train-spearman:0.786994	test-spearman:0.794300
# [171]	train-spearman:0.787020	test-spearman:0.794243
# [172]	train-spearman:0.786916	test-spearman:0.794091
# [173]	train-spearman:0.787113	test-spearman:0.794196
# [174]	train-spearman:0.787169	test-spearman:0.794314
# [175]	train-spearman:0.787190	test-spearman:0.794345
# [176]	train-spearman:0.787172	test-spearman:0.794341
# [177]	train-spearman:0.787472	test-spearman:0.794490
# [178]	train-spearman:0.787457	test-spearman:0.794472
# [179]	train-spearman:0.787466	test-spearman:0.794422
# [180]	train-spearman:0.787578	test-spearman:0.794504
# [181]	train-spearman:0.787572	test-spearman:0.794667
# [182]	train-spearman:0.787572	test-spearman:0.794630
# [183]	train-spearman:0.787654	test-spearman:0.794513
# [184]	train-spearman:0.787651	test-spearman:0.794516
# [185]	train-spearman:0.787866	test-spearman:0.794502
# [186]	train-spearman:0.787944	test-spearman:0.794536
# [187]	train-spearman:0.788024	test-spearman:0.794541
# [188]	train-spearman:0.788051	test-spearman:0.794566
# [189]	train-spearman:0.788219	test-spearman:0.794549
# [190]	train-spearman:0.788186	test-spearman:0.794511
# [191]	train-spearman:0.788155	test-spearman:0.794568
# [192]	train-spearman:0.788284	test-spearman:0.794475
# [193]	train-spearman:0.788333	test-spearman:0.794479
# [194]	train-spearman:0.788371	test-spearman:0.794541
# [195]	train-spearman:0.788348	test-spearman:0.794478
# [196]	train-spearman:0.788509	test-spearman:0.794652
# [197]	train-spearman:0.788578	test-spearman:0.794617
# [198]	train-spearman:0.788663	test-spearman:0.794556
# [199]	train-spearman:0.788730	test-spearman:0.794712
# [200]	train-spearman:0.788783	test-spearman:0.794819
# [201]	train-spearman:0.788894	test-spearman:0.794788
# [202]	train-spearman:0.788992	test-spearman:0.794808
# [203]	train-spearman:0.788985	test-spearman:0.794697
# [204]	train-spearman:0.788996	test-spearman:0.794717
# [205]	train-spearman:0.789032	test-spearman:0.794755
# [206]	train-spearman:0.789216	test-spearman:0.794831
# [207]	train-spearman:0.789244	test-spearman:0.794838
# [208]	train-spearman:0.789332	test-spearman:0.794815
# [209]	train-spearman:0.789387	test-spearman:0.794776
# [210]	train-spearman:0.789436	test-spearman:0.794721
# [211]	train-spearman:0.789411	test-spearman:0.794696
# [212]	train-spearman:0.789451	test-spearman:0.794647
# [213]	train-spearman:0.789639	test-spearman:0.794690
# [214]	train-spearman:0.789717	test-spearman:0.794634
# [215]	train-spearman:0.789977	test-spearman:0.794725
# [216]	train-spearman:0.790041	test-spearman:0.794669
# [217]	train-spearman:0.790084	test-spearman:0.794724
# [218]	train-spearman:0.790125	test-spearman:0.794688
# [219]	train-spearman:0.790104	test-spearman:0.794617
# [220]	train-spearman:0.790019	test-spearman:0.794509
# [221]	train-spearman:0.789984	test-spearman:0.794545
# [222]	train-spearman:0.789914	test-spearman:0.794469
# [223]	train-spearman:0.789916	test-spearman:0.794436
# [224]	train-spearman:0.789991	test-spearman:0.794312
# [225]	train-spearman:0.789968	test-spearman:0.794339
# [226]	train-spearman:0.790030	test-spearman:0.794393
# [227]	train-spearman:0.790162	test-spearman:0.794377
# [228]	train-spearman:0.790034	test-spearman:0.794226
# [229]	train-spearman:0.790095	test-spearman:0.794377
# [230]	train-spearman:0.790153	test-spearman:0.794327
# [231]	train-spearman:0.790230	test-spearman:0.794409
# [232]	train-spearman:0.790315	test-spearman:0.794470
# [233]	train-spearman:0.790044	test-spearman:0.794276
# [234]	train-spearman:0.789988	test-spearman:0.794267
# [235]	train-spearman:0.789980	test-spearman:0.794232
# [236]	train-spearman:0.790037	test-spearman:0.794170
# [237]	train-spearman:0.789898	test-spearman:0.794154
# [238]	train-spearman:0.790104	test-spearman:0.794193
# [239]	train-spearman:0.790128	test-spearman:0.794181
# [240]	train-spearman:0.790212	test-spearman:0.794127
# [241]	train-spearman:0.790339	test-spearman:0.794168
# [242]	train-spearman:0.790463	test-spearman:0.794239
# [243]	train-spearman:0.790505	test-spearman:0.794190
# [244]	train-spearman:0.790513	test-spearman:0.794147
# [245]	train-spearman:0.790552	test-spearman:0.794159
# [246]	train-spearman:0.790744	test-spearman:0.794192
# [247]	train-spearman:0.790746	test-spearman:0.794157
# [248]	train-spearman:0.790849	test-spearman:0.794220
# [249]	train-spearman:0.790926	test-spearman:0.794224
# [250]	train-spearman:0.791009	test-spearman:0.794255
# [251]	train-spearman:0.791021	test-spearman:0.794253
# [252]	train-spearman:0.791044	test-spearman:0.794321
# [253]	train-spearman:0.791036	test-spearman:0.794256
# [254]	train-spearman:0.791054	test-spearman:0.794246
# [255]	train-spearman:0.791013	test-spearman:0.794110
# [256]	train-spearman:0.791027	test-spearman:0.794117
# [257]	train-spearman:0.790912	test-spearman:0.794011
# [258]	train-spearman:0.790901	test-spearman:0.793924
# [259]	train-spearman:0.790829	test-spearman:0.793900
# [260]	train-spearman:0.790821	test-spearman:0.793880
# [261]	train-spearman:0.790893	test-spearman:0.793898
# [262]	train-spearman:0.791035	test-spearman:0.793915
# [263]	train-spearman:0.791065	test-spearman:0.793929
# [264]	train-spearman:0.791100	test-spearman:0.794016
# [265]	train-spearman:0.791209	test-spearman:0.794081
# [266]	train-spearman:0.791457	test-spearman:0.794178
# [267]	train-spearman:0.791466	test-spearman:0.794083
# [268]	train-spearman:0.791420	test-spearman:0.794066
# [269]	train-spearman:0.791350	test-spearman:0.794094
# [270]	train-spearman:0.791217	test-spearman:0.794096
# [271]	train-spearman:0.791343	test-spearman:0.794144
# [272]	train-spearman:0.791406	test-spearman:0.794112
# [273]	train-spearman:0.791563	test-spearman:0.794239
# [274]	train-spearman:0.791868	test-spearman:0.794513
# [275]	train-spearman:0.791811	test-spearman:0.794432
# [276]	train-spearman:0.791788	test-spearman:0.794349
# [277]	train-spearman:0.791897	test-spearman:0.794423
# [278]	train-spearman:0.791929	test-spearman:0.794474
# [279]	train-spearman:0.791958	test-spearman:0.794339
# [280]	train-spearman:0.791951	test-spearman:0.794361
# [281]	train-spearman:0.792137	test-spearman:0.794377
# [282]	train-spearman:0.792326	test-spearman:0.794691
# [283]	train-spearman:0.792554	test-spearman:0.794797
# [284]	train-spearman:0.792458	test-spearman:0.794783
# [285]	train-spearman:0.792461	test-spearman:0.794700
# [286]	train-spearman:0.792498	test-spearman:0.794663
# [287]	train-spearman:0.792528	test-spearman:0.794636
# [288]	train-spearman:0.792550	test-spearman:0.794650
# [289]	train-spearman:0.792581	test-spearman:0.794646
# [290]	train-spearman:0.792534	test-spearman:0.794617
# [291]	train-spearman:0.792489	test-spearman:0.794617
# [292]	train-spearman:0.792475	test-spearman:0.794641
# [293]	train-spearman:0.792473	test-spearman:0.794652
# [294]	train-spearman:0.792551	test-spearman:0.794712
# [295]	train-spearman:0.792434	test-spearman:0.794717
# [296]	train-spearman:0.792503	test-spearman:0.794700
# [297]	train-spearman:0.792517	test-spearman:0.794720
# [298]	train-spearman:0.792553	test-spearman:0.794846
# [299]	train-spearman:0.792639	test-spearman:0.794811
# [300]	train-spearman:0.792684	test-spearman:0.794810
# [301]	train-spearman:0.792766	test-spearman:0.794707
# [302]	train-spearman:0.792797	test-spearman:0.794779
# [303]	train-spearman:0.792796	test-spearman:0.794802
# [304]	train-spearman:0.792852	test-spearman:0.794833
# [305]	train-spearman:0.792881	test-spearman:0.794890
# [306]	train-spearman:0.792803	test-spearman:0.794810
# [307]	train-spearman:0.792825	test-spearman:0.794818
# [308]	train-spearman:0.792917	test-spearman:0.794988
# [309]	train-spearman:0.792964	test-spearman:0.794942
# [310]	train-spearman:0.792933	test-spearman:0.795000
# [311]	train-spearman:0.792985	test-spearman:0.794938
# [312]	train-spearman:0.793098	test-spearman:0.794990
# [313]	train-spearman:0.793083	test-spearman:0.795030
# [314]	train-spearman:0.793104	test-spearman:0.795025
# [315]	train-spearman:0.793155	test-spearman:0.795015
# [316]	train-spearman:0.793225	test-spearman:0.794962
# [317]	train-spearman:0.793301	test-spearman:0.794983
# [318]	train-spearman:0.793348	test-spearman:0.794996
# [319]	train-spearman:0.793430	test-spearman:0.794998
# [320]	train-spearman:0.793597	test-spearman:0.795029
# [321]	train-spearman:0.793740	test-spearman:0.795039
# [322]	train-spearman:0.793748	test-spearman:0.794980
# [323]	train-spearman:0.793775	test-spearman:0.794942
# [324]	train-spearman:0.793947	test-spearman:0.795057
# [325]	train-spearman:0.793998	test-spearman:0.795106
# [326]	train-spearman:0.794135	test-spearman:0.795290
# [327]	train-spearman:0.794125	test-spearman:0.795347
# [328]	train-spearman:0.794095	test-spearman:0.795337
# [329]	train-spearman:0.794147	test-spearman:0.795395
# [330]	train-spearman:0.794173	test-spearman:0.795540
# [331]	train-spearman:0.794055	test-spearman:0.795484
# [332]	train-spearman:0.794147	test-spearman:0.795480
# [333]	train-spearman:0.794122	test-spearman:0.795429
# [334]	train-spearman:0.794153	test-spearman:0.795473
# [335]	train-spearman:0.794195	test-spearman:0.795415
# [336]	train-spearman:0.794191	test-spearman:0.795430
# [337]	train-spearman:0.794176	test-spearman:0.795464
# [338]	train-spearman:0.794178	test-spearman:0.795421
# [339]	train-spearman:0.794173	test-spearman:0.795409
# [340]	train-spearman:0.794205	test-spearman:0.795375
# [341]	train-spearman:0.794146	test-spearman:0.795356
# [342]	train-spearman:0.794184	test-spearman:0.795343
# [343]	train-spearman:0.794115	test-spearman:0.795334
# [344]	train-spearman:0.794174	test-spearman:0.795365
# [345]	train-spearman:0.794110	test-spearman:0.795358
# [346]	train-spearman:0.794152	test-spearman:0.795339
# [347]	train-spearman:0.794155	test-spearman:0.795328
# [348]	train-spearman:0.794192	test-spearman:0.795304
# [349]	train-spearman:0.794268	test-spearman:0.795466
# [350]	train-spearman:0.794277	test-spearman:0.795451
# [351]	train-spearman:0.794279	test-spearman:0.795400
# [352]	train-spearman:0.794268	test-spearman:0.795395
# [353]	train-spearman:0.794314	test-spearman:0.795358
# [354]	train-spearman:0.794373	test-spearman:0.795314
# [355]	train-spearman:0.794389	test-spearman:0.795259
# [356]	train-spearman:0.794467	test-spearman:0.795328
# [357]	train-spearman:0.794360	test-spearman:0.795135
# [358]	train-spearman:0.794359	test-spearman:0.795205
# [359]	train-spearman:0.794383	test-spearman:0.795227
# [360]	train-spearman:0.794377	test-spearman:0.795261
# [361]	train-spearman:0.794436	test-spearman:0.795308
# [362]	train-spearman:0.794462	test-spearman:0.795402
# [363]	train-spearman:0.794498	test-spearman:0.795420
# [364]	train-spearman:0.794526	test-spearman:0.795430
# [365]	train-spearman:0.794553	test-spearman:0.795437
# [366]	train-spearman:0.794580	test-spearman:0.795438
# [367]	train-spearman:0.794611	test-spearman:0.795488
# [368]	train-spearman:0.794710	test-spearman:0.795540
# [369]	train-spearman:0.794605	test-spearman:0.795427
# [370]	train-spearman:0.794643	test-spearman:0.795429
# [371]	train-spearman:0.794710	test-spearman:0.795474
# [372]	train-spearman:0.794691	test-spearman:0.795458
# [373]	train-spearman:0.794749	test-spearman:0.795377
# [374]	train-spearman:0.794792	test-spearman:0.795401
# [375]	train-spearman:0.794812	test-spearman:0.795415
# [376]	train-spearman:0.794879	test-spearman:0.795481
# [377]	train-spearman:0.794932	test-spearman:0.795527
# [378]	train-spearman:0.794942	test-spearman:0.795496
# [379]	train-spearman:0.794955	test-spearman:0.795447
# [380]	train-spearman:0.794917	test-spearman:0.795395
# [381]	train-spearman:0.794906	test-spearman:0.795435
# [382]	train-spearman:0.794926	test-spearman:0.795441
# [383]	train-spearman:0.794899	test-spearman:0.795361
# [384]	train-spearman:0.794872	test-spearman:0.795341
# [385]	train-spearman:0.794920	test-spearman:0.795326
# [386]	train-spearman:0.794959	test-spearman:0.795296
# [387]	train-spearman:0.794956	test-spearman:0.795303
# [388]	train-spearman:0.794904	test-spearman:0.795296
# [389]	train-spearman:0.795049	test-spearman:0.795360
# [390]	train-spearman:0.795089	test-spearman:0.795357
# [391]	train-spearman:0.795079	test-spearman:0.795385
# [392]	train-spearman:0.795028	test-spearman:0.795327
# [393]	train-spearman:0.795007	test-spearman:0.795263
# [394]	train-spearman:0.794976	test-spearman:0.795231
# [395]	train-spearman:0.795068	test-spearman:0.795260
# [396]	train-spearman:0.795120	test-spearman:0.795322
# [397]	train-spearman:0.795257	test-spearman:0.795344
# [398]	train-spearman:0.795274	test-spearman:0.795335
# [399]	train-spearman:0.795345	test-spearman:0.795332
# [400]	train-spearman:0.795431	test-spearman:0.795264
# [401]	train-spearman:0.795414	test-spearman:0.795264
# [402]	train-spearman:0.795462	test-spearman:0.795259
# [403]	train-spearman:0.795442	test-spearman:0.795260
# [404]	train-spearman:0.795479	test-spearman:0.795275
# [405]	train-spearman:0.795568	test-spearman:0.795339
# [406]	train-spearman:0.795649	test-spearman:0.795324
# [407]	train-spearman:0.795794	test-spearman:0.795369
# [408]	train-spearman:0.795815	test-spearman:0.795334
# [409]	train-spearman:0.795809	test-spearman:0.795371
# [410]	train-spearman:0.795847	test-spearman:0.795331
# [411]	train-spearman:0.795875	test-spearman:0.795327
# [412]	train-spearman:0.795904	test-spearman:0.795316
# [413]	train-spearman:0.795927	test-spearman:0.795354
# [414]	train-spearman:0.795935	test-spearman:0.795333
# [415]	train-spearman:0.795968	test-spearman:0.795394
# [416]	train-spearman:0.795951	test-spearman:0.795363
# [417]	train-spearman:0.795924	test-spearman:0.795357
# [418]	train-spearman:0.795963	test-spearman:0.795381
# [419]	train-spearman:0.795973	test-spearman:0.795404
# [420]	train-spearman:0.795883	test-spearman:0.795388
# [421]	train-spearman:0.795939	test-spearman:0.795449
# [422]	train-spearman:0.795912	test-spearman:0.795493
# [423]	train-spearman:0.795955	test-spearman:0.795500
# [424]	train-spearman:0.795950	test-spearman:0.795504
# [425]	train-spearman:0.796017	test-spearman:0.795622
# [426]	train-spearman:0.796044	test-spearman:0.795637
# [427]	train-spearman:0.795994	test-spearman:0.795648
# [428]	train-spearman:0.795994	test-spearman:0.795604
# [429]	train-spearman:0.796020	test-spearman:0.795603
# [430]	train-spearman:0.796048	test-spearman:0.795593
# [431]	train-spearman:0.796054	test-spearman:0.795561
# [432]	train-spearman:0.796068	test-spearman:0.795573
# [433]	train-spearman:0.796134	test-spearman:0.795519
# [434]	train-spearman:0.796190	test-spearman:0.795543
# [435]	train-spearman:0.796217	test-spearman:0.795601
# [436]	train-spearman:0.796277	test-spearman:0.795672
# [437]	train-spearman:0.796243	test-spearman:0.795679
# [438]	train-spearman:0.796258	test-spearman:0.795659
# [439]	train-spearman:0.796257	test-spearman:0.795647
# [440]	train-spearman:0.796260	test-spearman:0.795605
# [441]	train-spearman:0.796266	test-spearman:0.795622
# [442]	train-spearman:0.796228	test-spearman:0.795624
# [443]	train-spearman:0.796255	test-spearman:0.795606
# [444]	train-spearman:0.796270	test-spearman:0.795597
# [445]	train-spearman:0.796288	test-spearman:0.795607
# [446]	train-spearman:0.796294	test-spearman:0.795591
# [447]	train-spearman:0.796299	test-spearman:0.795563
# [448]	train-spearman:0.796318	test-spearman:0.795542
# [449]	train-spearman:0.796301	test-spearman:0.795529
# [450]	train-spearman:0.796324	test-spearman:0.795483
# [451]	train-spearman:0.796381	test-spearman:0.795586
# [452]	train-spearman:0.796381	test-spearman:0.795554
# [453]	train-spearman:0.796400	test-spearman:0.795609
# [454]	train-spearman:0.796411	test-spearman:0.795617
# [455]	train-spearman:0.796438	test-spearman:0.795680
# [456]	train-spearman:0.796452	test-spearman:0.795649
# [457]	train-spearman:0.796498	test-spearman:0.795687
# [458]	train-spearman:0.796539	test-spearman:0.795714
# [459]	train-spearman:0.796500	test-spearman:0.795721
# [460]	train-spearman:0.796474	test-spearman:0.795674
# [461]	train-spearman:0.796511	test-spearman:0.795740
# [462]	train-spearman:0.796437	test-spearman:0.795724
# [463]	train-spearman:0.796416	test-spearman:0.795644
# [464]	train-spearman:0.796388	test-spearman:0.795629
# [465]	train-spearman:0.796397	test-spearman:0.795628
# [466]	train-spearman:0.796329	test-spearman:0.795607
# [467]	train-spearman:0.796403	test-spearman:0.795639
# [468]	train-spearman:0.796417	test-spearman:0.795676
# [469]	train-spearman:0.796458	test-spearman:0.795721
# [470]	train-spearman:0.796439	test-spearman:0.795739
# [471]	train-spearman:0.796405	test-spearman:0.795683
# [472]	train-spearman:0.796407	test-spearman:0.795678
# [473]	train-spearman:0.796416	test-spearman:0.795660
# [474]	train-spearman:0.796468	test-spearman:0.795713
# [475]	train-spearman:0.796191	test-spearman:0.795577
# [476]	train-spearman:0.796214	test-spearman:0.795678
# [477]	train-spearman:0.796220	test-spearman:0.795663
# [478]	train-spearman:0.796220	test-spearman:0.795654
# [479]	train-spearman:0.796223	test-spearman:0.795664
# [480]	train-spearman:0.796228	test-spearman:0.795679
# [481]	train-spearman:0.796256	test-spearman:0.795687
# [482]	train-spearman:0.796349	test-spearman:0.795790
# [483]	train-spearman:0.796420	test-spearman:0.795814
# [484]	train-spearman:0.796428	test-spearman:0.795784
# [485]	train-spearman:0.796500	test-spearman:0.795756
# [486]	train-spearman:0.796511	test-spearman:0.795763
# [487]	train-spearman:0.796581	test-spearman:0.795785
# [488]	train-spearman:0.796574	test-spearman:0.795751
# [489]	train-spearman:0.796597	test-spearman:0.795763
# [490]	train-spearman:0.796622	test-spearman:0.795759
# [491]	train-spearman:0.796660	test-spearman:0.795792
# [492]	train-spearman:0.796672	test-spearman:0.795783
# [493]	train-spearman:0.796674	test-spearman:0.795759
# [494]	train-spearman:0.796672	test-spearman:0.795696
# [495]	train-spearman:0.796668	test-spearman:0.795668
# [496]	train-spearman:0.796687	test-spearman:0.795648
# [497]	train-spearman:0.796674	test-spearman:0.795669
# [498]	train-spearman:0.796679	test-spearman:0.795690
# [499]	train-spearman:0.796688	test-spearman:0.795678
# [500]	train-spearman:0.796701	test-spearman:0.795683

# %%
############################ HYPERPARAM SEARCH ####################################

# Dumb grid search (DONT RUN)

validation_pearsons <- list()
iter <- 0

for (max_depth in 4:7) {
  for (alpha in c(0,500,750, 1000)) {
    for (colsample in c(0.3,0.4,0.5)) {
      for (lambda in c(1, 500, 1000)) {
  
      
      param <- list(objective = "count:poisson",
                    eval_metric = evalerror,
                    subsample = 0.8,
                    colsample_bytree= colsample,
                    lambda = lambda,
                    alpha = alpha)
      
        model = xgb.train(data = xgb_train,
                          max.depth = max_depth,
                          watchlist=watchlist,
                          nrounds = 500,
                          params = param,
                          verbose = 0)
        validation_pearsons[[paste(max_depth,
                             alpha,
                             colsample,
                             lambda)]] <- model$evaluation_log$test_spearman
        iter <- iter + 1
        print(paste("iter", iter, max_depth, alpha, colsample, lambda, max(model$evaluation_log$test_spearman)))
      }
    }
  }
}


# best 6 750 0.4 1000 with 0.7817005
# after adding more features and redoing hyperparam search (Apr 3)
# best: 6 750 0.3 1000 with 0.7844057
# after adding features meta gene features
# best 6 750 0.3 500" with 0.7991933

# %%
losses_df <- data.frame(
  iteration = 1:length(validation_pearsons[[1]]),
  stack(sapply(validation_pearsons, `length<-`, max(lengths(validation_pearsons))))
)

# Rename the columns
colnames(losses_df) <- c("iteration", "iter", "hyperparameter","loss")

# Plot the losses using ggplot2
ggplot(data = losses_df, aes(x = iteration, y = loss, color = as.factor(hyperparameter))) +
  geom_line() +
  labs(title = "Losses for Different Hyperparameters",
       x = "Iteration",
       y = "Pearsons on Validation Set",
       color = "Max Depth") +
       ylim(0.75,0.8) +
       theme_minimal() +
       theme(legend.position="none") 
        
  

  print(losses_df[which.max(losses_df$loss),])
# Out:
# Warning message:
# “Removed 2644 rows containing missing values (geom_path).”
#       iteration iter hyperparameter      loss
# 46388       388  388 6 750 0.3 1000 0.7844057
# plot without title

# %% [markdown]
# Based off of the parameters that we found from the grid search, we trained the model on both the training and validation data.

# %%
# Train optimal model with train and validation data
train_and_val <- rbind(train_complete,val_complete)

xgb_train_and_val <- xgb.DMatrix(data =  data.matrix(train_and_val[,-ncol(train_and_val)]),
                        label = train_and_val[,ncol(train_and_val)])

# take the param from the best model
param <- list(objective = "count:poisson", 
              eval_metric = evalerror,
              subsample = 0.8,
              colsample_bytree= 0.3,
              lambda = 500,
              alpha = 750)


final <- xgboost(data = xgb_train_and_val,
                max.depth = 6,
                nrounds = 480,
                params = param)
# Out:
# [1]	train-spearman:0.590321
# [2]	train-spearman:0.599342
# [3]	train-spearman:0.606688
# [4]	train-spearman:0.609248
# [5]	train-spearman:0.611689
# [6]	train-spearman:0.643123
# [7]	train-spearman:0.665295
# [8]	train-spearman:0.684047
# [9]	train-spearman:0.688630
# [10]	train-spearman:0.689022
# [11]	train-spearman:0.692178
# [12]	train-spearman:0.692216
# [13]	train-spearman:0.697502
# [14]	train-spearman:0.718321
# [15]	train-spearman:0.730447
# [16]	train-spearman:0.739726
# [17]	train-spearman:0.744097
# [18]	train-spearman:0.747209
# [19]	train-spearman:0.750337
# [20]	train-spearman:0.752869
# [21]	train-spearman:0.753720
# [22]	train-spearman:0.756971
# [23]	train-spearman:0.759495
# [24]	train-spearman:0.759328
# [25]	train-spearman:0.762030
# [26]	train-spearman:0.765024
# [27]	train-spearman:0.766512
# [28]	train-spearman:0.767362
# [29]	train-spearman:0.767603
# [30]	train-spearman:0.768332
# [31]	train-spearman:0.768910
# [32]	train-spearman:0.769002
# [33]	train-spearman:0.769651
# [34]	train-spearman:0.771716
# [35]	train-spearman:0.773014
# [36]	train-spearman:0.773050
# [37]	train-spearman:0.773085
# [38]	train-spearman:0.773443
# [39]	train-spearman:0.773859
# [40]	train-spearman:0.774034
# [41]	train-spearman:0.773757
# [42]	train-spearman:0.773724
# [43]	train-spearman:0.774094
# [44]	train-spearman:0.774216
# [45]	train-spearman:0.774390
# [46]	train-spearman:0.774916
# [47]	train-spearman:0.774899
# [48]	train-spearman:0.775215
# [49]	train-spearman:0.775555
# [50]	train-spearman:0.775888
# [51]	train-spearman:0.775937
# [52]	train-spearman:0.776523
# [53]	train-spearman:0.776789
# [54]	train-spearman:0.776793
# [55]	train-spearman:0.777106
# [56]	train-spearman:0.777241
# [57]	train-spearman:0.777471
# [58]	train-spearman:0.777422
# [59]	train-spearman:0.777669
# [60]	train-spearman:0.778064
# [61]	train-spearman:0.778445
# [62]	train-spearman:0.778452
# [63]	train-spearman:0.778353
# [64]	train-spearman:0.779203
# [65]	train-spearman:0.779508
# [66]	train-spearman:0.779543
# [67]	train-spearman:0.779970
# [68]	train-spearman:0.780187
# [69]	train-spearman:0.780527
# [70]	train-spearman:0.780516
# [71]	train-spearman:0.780316
# [72]	train-spearman:0.780453
# [73]	train-spearman:0.780625
# [74]	train-spearman:0.780576
# [75]	train-spearman:0.780801
# [76]	train-spearman:0.781052
# [77]	train-spearman:0.780804
# [78]	train-spearman:0.781052
# [79]	train-spearman:0.780937
# [80]	train-spearman:0.781089
# [81]	train-spearman:0.781296
# [82]	train-spearman:0.781340
# [83]	train-spearman:0.781455
# [84]	train-spearman:0.781397
# [85]	train-spearman:0.781775
# [86]	train-spearman:0.781892
# [87]	train-spearman:0.782209
# [88]	train-spearman:0.782649
# [89]	train-spearman:0.782554
# [90]	train-spearman:0.782725
# [91]	train-spearman:0.783122
# [92]	train-spearman:0.783338
# [93]	train-spearman:0.783135
# [94]	train-spearman:0.783384
# [95]	train-spearman:0.783582
# [96]	train-spearman:0.783685
# [97]	train-spearman:0.783723
# [98]	train-spearman:0.784168
# [99]	train-spearman:0.784304
# [100]	train-spearman:0.784437
# [101]	train-spearman:0.784613
# [102]	train-spearman:0.784730
# [103]	train-spearman:0.785056
# [104]	train-spearman:0.785190
# [105]	train-spearman:0.785217
# [106]	train-spearman:0.785293
# [107]	train-spearman:0.785379
# [108]	train-spearman:0.785451
# [109]	train-spearman:0.785658
# [110]	train-spearman:0.785724
# [111]	train-spearman:0.785782
# [112]	train-spearman:0.785761
# [113]	train-spearman:0.785958
# [114]	train-spearman:0.786008
# [115]	train-spearman:0.786071
# [116]	train-spearman:0.786135
# [117]	train-spearman:0.786386
# [118]	train-spearman:0.786780
# [119]	train-spearman:0.787043
# [120]	train-spearman:0.787045
# [121]	train-spearman:0.787273
# [122]	train-spearman:0.787342
# [123]	train-spearman:0.787408
# [124]	train-spearman:0.787573
# [125]	train-spearman:0.787645
# [126]	train-spearman:0.787834
# [127]	train-spearman:0.787977
# [128]	train-spearman:0.788178
# [129]	train-spearman:0.788267
# [130]	train-spearman:0.788289
# [131]	train-spearman:0.788309
# [132]	train-spearman:0.788342
# [133]	train-spearman:0.788425
# [134]	train-spearman:0.788124
# [135]	train-spearman:0.787997
# [136]	train-spearman:0.788212
# [137]	train-spearman:0.788309
# [138]	train-spearman:0.788132
# [139]	train-spearman:0.788209
# [140]	train-spearman:0.788255
# [141]	train-spearman:0.788228
# [142]	train-spearman:0.788306
# [143]	train-spearman:0.788351
# [144]	train-spearman:0.788630
# [145]	train-spearman:0.788677
# [146]	train-spearman:0.788926
# [147]	train-spearman:0.789027
# [148]	train-spearman:0.789044
# [149]	train-spearman:0.789186
# [150]	train-spearman:0.789225
# [151]	train-spearman:0.789345
# [152]	train-spearman:0.789385
# [153]	train-spearman:0.789410
# [154]	train-spearman:0.789538
# [155]	train-spearman:0.789580
# [156]	train-spearman:0.789587
# [157]	train-spearman:0.789739
# [158]	train-spearman:0.790076
# [159]	train-spearman:0.790079
# [160]	train-spearman:0.790164
# [161]	train-spearman:0.790126
# [162]	train-spearman:0.790048
# [163]	train-spearman:0.790095
# [164]	train-spearman:0.790131
# [165]	train-spearman:0.790069
# [166]	train-spearman:0.790110
# [167]	train-spearman:0.790123
# [168]	train-spearman:0.790178
# [169]	train-spearman:0.790233
# [170]	train-spearman:0.790290
# [171]	train-spearman:0.790354
# [172]	train-spearman:0.790385
# [173]	train-spearman:0.790427
# [174]	train-spearman:0.790405
# [175]	train-spearman:0.790444
# [176]	train-spearman:0.790457
# [177]	train-spearman:0.790645
# [178]	train-spearman:0.790838
# [179]	train-spearman:0.790747
# [180]	train-spearman:0.790989
# [181]	train-spearman:0.791073
# [182]	train-spearman:0.791143
# [183]	train-spearman:0.791169
# [184]	train-spearman:0.791083
# [185]	train-spearman:0.791142
# [186]	train-spearman:0.791225
# [187]	train-spearman:0.791212
# [188]	train-spearman:0.791359
# [189]	train-spearman:0.791492
# [190]	train-spearman:0.791581
# [191]	train-spearman:0.791585
# [192]	train-spearman:0.791674
# [193]	train-spearman:0.791719
# [194]	train-spearman:0.791732
# [195]	train-spearman:0.791996
# [196]	train-spearman:0.791943
# [197]	train-spearman:0.791963
# [198]	train-spearman:0.791996
# [199]	train-spearman:0.791994
# [200]	train-spearman:0.792041
# [201]	train-spearman:0.791987
# [202]	train-spearman:0.791964
# [203]	train-spearman:0.792213
# [204]	train-spearman:0.792335
# [205]	train-spearman:0.792410
# [206]	train-spearman:0.792477
# [207]	train-spearman:0.792543
# [208]	train-spearman:0.792587
# [209]	train-spearman:0.792804
# [210]	train-spearman:0.792835
# [211]	train-spearman:0.792813
# [212]	train-spearman:0.792801
# [213]	train-spearman:0.792857
# [214]	train-spearman:0.792941
# [215]	train-spearman:0.793168
# [216]	train-spearman:0.793241
# [217]	train-spearman:0.793306
# [218]	train-spearman:0.793205
# [219]	train-spearman:0.793240
# [220]	train-spearman:0.793239
# [221]	train-spearman:0.793350
# [222]	train-spearman:0.793501
# [223]	train-spearman:0.793516
# [224]	train-spearman:0.793523
# [225]	train-spearman:0.793487
# [226]	train-spearman:0.793472
# [227]	train-spearman:0.793551
# [228]	train-spearman:0.793528
# [229]	train-spearman:0.793671
# [230]	train-spearman:0.793698
# [231]	train-spearman:0.793732
# [232]	train-spearman:0.793765
# [233]	train-spearman:0.793750
# [234]	train-spearman:0.793751
# [235]	train-spearman:0.794009
# [236]	train-spearman:0.794099
# [237]	train-spearman:0.794093
# [238]	train-spearman:0.794133
# [239]	train-spearman:0.794129
# [240]	train-spearman:0.794198
# [241]	train-spearman:0.794263
# [242]	train-spearman:0.794421
# [243]	train-spearman:0.794434
# [244]	train-spearman:0.794482
# [245]	train-spearman:0.794488
# [246]	train-spearman:0.794797
# [247]	train-spearman:0.794890
# [248]	train-spearman:0.795030
# [249]	train-spearman:0.795078
# [250]	train-spearman:0.794970
# [251]	train-spearman:0.794993
# [252]	train-spearman:0.795070
# [253]	train-spearman:0.795214
# [254]	train-spearman:0.795246
# [255]	train-spearman:0.795335
# [256]	train-spearman:0.795395
# [257]	train-spearman:0.795426
# [258]	train-spearman:0.795618
# [259]	train-spearman:0.795899
# [260]	train-spearman:0.796042
# [261]	train-spearman:0.796036
# [262]	train-spearman:0.796076
# [263]	train-spearman:0.796163
# [264]	train-spearman:0.796185
# [265]	train-spearman:0.796219
# [266]	train-spearman:0.796260
# [267]	train-spearman:0.796451
# [268]	train-spearman:0.796605
# [269]	train-spearman:0.796702
# [270]	train-spearman:0.796800
# [271]	train-spearman:0.796922
# [272]	train-spearman:0.796906
# [273]	train-spearman:0.796919
# [274]	train-spearman:0.796843
# [275]	train-spearman:0.796833
# [276]	train-spearman:0.796845
# [277]	train-spearman:0.796878
# [278]	train-spearman:0.796950
# [279]	train-spearman:0.796927
# [280]	train-spearman:0.796976
# [281]	train-spearman:0.797019
# [282]	train-spearman:0.797162
# [283]	train-spearman:0.797194
# [284]	train-spearman:0.797299
# [285]	train-spearman:0.797202
# [286]	train-spearman:0.797203
# [287]	train-spearman:0.797233
# [288]	train-spearman:0.797268
# [289]	train-spearman:0.797314
# [290]	train-spearman:0.797466
# [291]	train-spearman:0.797511
# [292]	train-spearman:0.797530
# [293]	train-spearman:0.797568
# [294]	train-spearman:0.797582
# [295]	train-spearman:0.797540
# [296]	train-spearman:0.797557
# [297]	train-spearman:0.797666
# [298]	train-spearman:0.797728
# [299]	train-spearman:0.797787
# [300]	train-spearman:0.797910
# [301]	train-spearman:0.797899
# [302]	train-spearman:0.797965
# [303]	train-spearman:0.797965
# [304]	train-spearman:0.798043
# [305]	train-spearman:0.797891
# [306]	train-spearman:0.797916
# [307]	train-spearman:0.797988
# [308]	train-spearman:0.798068
# [309]	train-spearman:0.798186
# [310]	train-spearman:0.798216
# [311]	train-spearman:0.798253
# [312]	train-spearman:0.798278
# [313]	train-spearman:0.798307
# [314]	train-spearman:0.798332
# [315]	train-spearman:0.798371
# [316]	train-spearman:0.798447
# [317]	train-spearman:0.798466
# [318]	train-spearman:0.798553
# [319]	train-spearman:0.798570
# [320]	train-spearman:0.798546
# [321]	train-spearman:0.798601
# [322]	train-spearman:0.798603
# [323]	train-spearman:0.798646
# [324]	train-spearman:0.798645
# [325]	train-spearman:0.798798
# [326]	train-spearman:0.798825
# [327]	train-spearman:0.798789
# [328]	train-spearman:0.798778
# [329]	train-spearman:0.798774
# [330]	train-spearman:0.798822
# [331]	train-spearman:0.798927
# [332]	train-spearman:0.798801
# [333]	train-spearman:0.798826
# [334]	train-spearman:0.798892
# [335]	train-spearman:0.798874
# [336]	train-spearman:0.798913
# [337]	train-spearman:0.798927
# [338]	train-spearman:0.798980
# [339]	train-spearman:0.799054
# [340]	train-spearman:0.798974
# [341]	train-spearman:0.799009
# [342]	train-spearman:0.799031
# [343]	train-spearman:0.799033
# [344]	train-spearman:0.799010
# [345]	train-spearman:0.798995
# [346]	train-spearman:0.798985
# [347]	train-spearman:0.798905
# [348]	train-spearman:0.798954
# [349]	train-spearman:0.798976
# [350]	train-spearman:0.799001
# [351]	train-spearman:0.798997
# [352]	train-spearman:0.798993
# [353]	train-spearman:0.798994
# [354]	train-spearman:0.798989
# [355]	train-spearman:0.799036
# [356]	train-spearman:0.799078
# [357]	train-spearman:0.799064
# [358]	train-spearman:0.799101
# [359]	train-spearman:0.799109
# [360]	train-spearman:0.799197
# [361]	train-spearman:0.799255
# [362]	train-spearman:0.799247
# [363]	train-spearman:0.799269
# [364]	train-spearman:0.799331
# [365]	train-spearman:0.799324
# [366]	train-spearman:0.799328
# [367]	train-spearman:0.799320
# [368]	train-spearman:0.799407
# [369]	train-spearman:0.799455
# [370]	train-spearman:0.799453
# [371]	train-spearman:0.799371
# [372]	train-spearman:0.799393
# [373]	train-spearman:0.799415
# [374]	train-spearman:0.799391
# [375]	train-spearman:0.799402
# [376]	train-spearman:0.799380
# [377]	train-spearman:0.799353
# [378]	train-spearman:0.799416
# [379]	train-spearman:0.799463
# [380]	train-spearman:0.799467
# [381]	train-spearman:0.799485
# [382]	train-spearman:0.799531
# [383]	train-spearman:0.799598
# [384]	train-spearman:0.799651
# [385]	train-spearman:0.799650
# [386]	train-spearman:0.799663
# [387]	train-spearman:0.799695
# [388]	train-spearman:0.799683
# [389]	train-spearman:0.799691
# [390]	train-spearman:0.799723
# [391]	train-spearman:0.799832
# [392]	train-spearman:0.799853
# [393]	train-spearman:0.799845
# [394]	train-spearman:0.799916
# [395]	train-spearman:0.799957
# [396]	train-spearman:0.799947
# [397]	train-spearman:0.799948
# [398]	train-spearman:0.799963
# [399]	train-spearman:0.800013
# [400]	train-spearman:0.800052
# [401]	train-spearman:0.800001
# [402]	train-spearman:0.800021
# [403]	train-spearman:0.800034
# [404]	train-spearman:0.800024
# [405]	train-spearman:0.800041
# [406]	train-spearman:0.800031
# [407]	train-spearman:0.800028
# [408]	train-spearman:0.800047
# [409]	train-spearman:0.800033
# [410]	train-spearman:0.800027
# [411]	train-spearman:0.799980
# [412]	train-spearman:0.800032
# [413]	train-spearman:0.800114
# [414]	train-spearman:0.800137
# [415]	train-spearman:0.800157
# [416]	train-spearman:0.800161
# [417]	train-spearman:0.800165
# [418]	train-spearman:0.800224
# [419]	train-spearman:0.800280
# [420]	train-spearman:0.800295
# [421]	train-spearman:0.800288
# [422]	train-spearman:0.800225
# [423]	train-spearman:0.800298
# [424]	train-spearman:0.800327
# [425]	train-spearman:0.800329
# [426]	train-spearman:0.800355
# [427]	train-spearman:0.800388
# [428]	train-spearman:0.800429
# [429]	train-spearman:0.800450
# [430]	train-spearman:0.800481
# [431]	train-spearman:0.800504
# [432]	train-spearman:0.800555
# [433]	train-spearman:0.800569
# [434]	train-spearman:0.800600
# [435]	train-spearman:0.800626
# [436]	train-spearman:0.800645
# [437]	train-spearman:0.800650
# [438]	train-spearman:0.800662
# [439]	train-spearman:0.800716
# [440]	train-spearman:0.800705
# [441]	train-spearman:0.800707
# [442]	train-spearman:0.800744
# [443]	train-spearman:0.800752
# [444]	train-spearman:0.800790
# [445]	train-spearman:0.800838
# [446]	train-spearman:0.800928
# [447]	train-spearman:0.800866
# [448]	train-spearman:0.800895
# [449]	train-spearman:0.800922
# [450]	train-spearman:0.800955
# [451]	train-spearman:0.800977
# [452]	train-spearman:0.801035
# [453]	train-spearman:0.801076
# [454]	train-spearman:0.801083
# [455]	train-spearman:0.801086
# [456]	train-spearman:0.801055
# [457]	train-spearman:0.801052
# [458]	train-spearman:0.801096
# [459]	train-spearman:0.801106
# [460]	train-spearman:0.801111
# [461]	train-spearman:0.801123
# [462]	train-spearman:0.801170
# [463]	train-spearman:0.801186
# [464]	train-spearman:0.801160
# [465]	train-spearman:0.801158
# [466]	train-spearman:0.801076
# [467]	train-spearman:0.801113
# [468]	train-spearman:0.801179
# [469]	train-spearman:0.801175
# [470]	train-spearman:0.801135
# [471]	train-spearman:0.801153
# [472]	train-spearman:0.801150
# [473]	train-spearman:0.801191
# [474]	train-spearman:0.801214
# [475]	train-spearman:0.801196
# [476]	train-spearman:0.801203
# [477]	train-spearman:0.801211
# [478]	train-spearman:0.801191
# [479]	train-spearman:0.801243
# [480]	train-spearman:0.801213

# %%
# Look at feature importances 

feature_importance <- xgboost::xgb.importance(model = final)
xgboost::xgb.plot.importance(feature_importance)
#xgb.plot.shap(data.matrix(xgb_train_and_val[,-ncol(xgb_train_and_val)]), model = final,top_n = 10)
#xgb.plot.shap.summary(data.matrix(xgb_train_and_val[,-ncol(xgb_train_and_val)]), model = final)
# Out:
# plot without title

# %% [markdown]
# ## Work Package 1.3 - Prediction on Test Data (Evaluation Metric)

# %% [markdown]
# Please note that we did not follow the code chunks provided in the original skeleton but ensured that the submission csv followed the required format.

# %%
# Using the model trained in WP 1.2, make predictions on the test data (chr 1 of cell line X3).
# Store predictions in a variable called "pred" which is a numpy array.
# ---------------------------INSERT CODE HERE---------------------------

# Write down the predicted values
pred_y = predict(final, xgb_real_test)

pred <- data.frame("gene_name" = genesTest$gene_name,
                    "gex_predicted" = pred_y,
                    row.names = 0:(length(pred_y)-1))

# write.csv(pred, file = "gex_predicted.csv",row.names = T,quote = FALSE)


# ----------------------------------------------------------------------

# Check if "pred" meets the specified constraints
print(is.numeric(pred$gex_predicted))
print(nrow(pred) == length(genesTest$gene_name))
# Out:
# [1] TRUE
# [1] TRUE

# %% [markdown]
# #### Store Predictions in the Required Format

# %%
# Store predictions in a ZIP.
# Upload this zip on the project website under "Your submission".
# Zip this notebook along with the conda environment (and README, optional) and upload this under "Your code".

save_dir <- getwd()  # TODO
file_name <- 'gex_predicted.csv'         # PLEASE DO NOT CHANGE THIS
zip_name <- "Jung_HuiJeong_Project1.zip" # TODO
save_path <- paste(save_dir, zip_name, sep="/")

write.csv(pred, file = "gex_predicted.csv",row.names = T,quote = FALSE)

# # Create the zip file
# utils::zip(zip_name, files = c(file_name))

# # Move the zip file to the save directory
# file.rename(zip_name, save_path)

# # Remove the csv file
# file.remove(file_name)
